# %% [markdown]
# # Visualizing Code-N-Collab User Data

# %%
import seaborn as sns
import pandas as pd

# %%
user_data = pd.read_csv("users.csv")
sns.countplot(data=user_data,x="Avatar",hue="Country")

# %%
user_data.columns
import matplotlib.pyplot as plt

# %%
null_data = user_data.isnull().sum()
#sns.countplot(data=Null_data,x="AtCoder")

# %%
null_data = pd.DataFrame(null_data)

# %%
null_data = null_data.reset_index()

# %%
null_data.head()
# Out:
#         index    0
# 0     AtCoder  112
# 1      Avatar    0
# 2       Blogs    0
# 3    Codechef  105
# 4  Codeforces   75

# %%
null_data.columns = ["Type","Count"]
plt.figure(figsize=(30,10))
sns.barplot(x = "Type",y="Count",data=null_data)

# %%
user_data.head()
# Out:
#                                 AtCoder  Avatar  \
# 0                                   NaN       4
# 1                                   NaN       5
# 2                                   NaN       1
# 3                                   NaN       5
# 4  https://atcoder.jp/users/AdnanShamsi       2
#
#                                                Blogs  \
# 0              [{"$oid":"60d3720c80dd9740309fd46d"}]
# 1                                                 []
# 2                                                 []
# 3  [{"$oid":"60d466f3dd2f8700043da13d"},{"$oid":"...
# 4  [{"$oid":"60d46baedd2f8700043da141"},{"$oid":"...
#
#                                      Codechef  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3     https://www.codechef.com/users/athar_12
# 4  https://www.codechef.com/users/adnanshamsi
#
#                                    Codeforces CodeforcesHandle Country  \
# 0                                         NaN          KickAss   India
# 1                                         NaN          Tourist   India
# 2                                         NaN              NaN     NaN
# 3      https://codeforces.com/profile/KickAss          KickAss   India
# 4  https://codeforces.com/profile/AdnanShamsi      AdnanShamsi   India
#
#    Deleted         Designation                       Email  ...  \
# 0    False  Software Developer      code.gennady@gmail.com  ...
# 1    False        Organistaion       codencollab@gmail.com  ...
# 2    False                 NaN        krishdevdb@gmail.com  ...
# 3    False  Software Developer      mohd.rule123@gmail.com  ...
# 4    False       Web Developer  adnanshamsi12345@gmail.com  ...
#
#                                             Linkedin                     Moto  \
# 0                                                NaN  Just do what you love !
# 1                                                NaN  Just do what you love !
# 2                                                NaN                      NaN
# 3  https://www.linkedin.com/in/athar-mohammad-340...  Just do what you love !
# 4  https://www.linkedin.com/in/adnan-shamsi-58303...   Keep calm and carry on
#
#             Name SuperUser Verified  __v                       _id  \
# 0     Mohd Athar     False     True    1  60d371d980dd9740309fd46c
# 1  Code N Collab     False     True    0  60d37a9c3abcd00004964dee
# 2    Krish Gupta     False     True    0  60d3ff41f432810004b25ca6
# 3     Mohd Athar      True     True    5  60d464f0dd2f8700043da13c
# 4   adnan shamsi      True     True    6  60d46b8edd2f8700043da140
#
#                   createdAt  \
# 0  2021-06-23T17:39:37.726Z
# 1  2021-06-23T18:17:00.881Z
# 2  2021-06-24T03:42:57.721Z
# 3  2021-06-24T10:56:48.656Z
# 4  2021-06-24T11:25:02.235Z
#
#                                                token                 updatedAt
# 0                                                NaN  2021-07-04T12:34:40.483Z
# 1                                                NaN  2021-07-04T12:34:55.368Z
# 2                                                NaN  2021-06-24T03:43:14.818Z
# 3  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJfaWQiO...  2021-07-11T08:48:30.724Z
# 4                                                NaN  2021-07-01T06:49:06.917Z
#
# [5 rows x 22 columns]

# %%
country_data = user_data.groupby("Country").count()
country_data.head()
# Out:
#              AtCoder  Avatar  Blogs  Codechef  Codeforces  CodeforcesHandle  \
# Country
# Afghanistan        0       2      2         0           1                 1
# Antarctica         1       1      1         1           1                 1
# Argentina          0       1      1         0           1                 1
# Bangladesh         1       5      5         1           2                 5
# Canada             0       1      1         0           1                 1
#
#              Deleted  Designation  Email  Github  ...  Linkedin  Moto  Name  \
# Country                                           ...
# Afghanistan        2            1      2       0  ...         0     1     2
# Antarctica         1            1      1       1  ...         1     1     1
# Argentina          1            1      1       0  ...         0     1     1
# Bangladesh         5            3      5       1  ...         1     1     5
# Canada             1            0      1       0  ...         0     0     1
#
#              SuperUser  Verified  __v  _id  createdAt  token  updatedAt
# Country
# Afghanistan          2         2    2    2          2      2          2
# Antarctica           1         1    1    1          1      1          1
# Argentina            1         1    1    1          1      1          1
# Bangladesh           5         5    5    5          5      5          5
# Canada               1         1    1    1          1      1          1
#
# [5 rows x 21 columns]

# %%
country_data.index
# Out:
# Index(['Afghanistan', 'Antarctica', 'Argentina', 'Bangladesh', 'Canada',
#        'India', 'Indonesia', 'Iran', 'Peru', 'Russian Federation', 'Samoa',
#        'Spain', 'United States', 'Vietnam'],
#       dtype='object', name='Country')

# %%
country_count = country_data["Email"].values

# %%
plt.figure(figsize=(15,15))
plt.pie(country_count,labels=country_data.index,explode=[0.1 for i in range(len(country_data.index))] ,autopct="%1.1f%%");

# %%
user_data["createdAt"] = pd.to_datetime(user_data['createdAt'])
user_data["createdAt"] = pd.to_datetime(user_data["createdAt"],format='%Y%m%d')
